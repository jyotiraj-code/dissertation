# %%
import mv

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#The ALPHA VANTAGE STOCKLIST API 1F4922R2LOBSW9O1

# %%
# Example usage
stocks = ["TCS", "MSFT", "NVDA"]
start_date = "2020-01-01"
end_date = "2023-02-01"
# api_key = "1F4922R2LOBSW9O1"

mvo = mv.MeanVarianceOptimization(stocks, start_date, end_date)
er = mvo.expected_returns()

print(er)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker
# MSFT    0.203235
# NVDA    0.339812
# TCS     0.463910
# Name: mkt, dtype: float64

# %%
# !kaggle datasets list -s stocks
# Out:
# usage: kaggle [-h] [-v] [-W]
#               {competitions,c,datasets,d,kernels,k,models,m,files,f,config}
#               ...
# kaggle: error: unrecognized arguments: Stocks Dataset

# %%
import kaggle
kaggle.api.authenticate()

# %%
kaggle.api.dataset_download_files("soumendraprasad/nifty50-stocks", unzip=True, path = '.')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/soumendraprasad/nifty50-stocks

# %%
kaggle.api.dataset_metadata("soumendraprasad/nifty50-stocks", path = '.')
# Out:
# '.\\dataset-metadata.json'

# %%
datasets = kaggle.api.dataset_list_files("soumendraprasad/nifty50-stocks")
print(datasets)

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/508.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/508.0 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/508.0 kB 667.8 kB/s eta 0:00:01
#    ------- ------------------------------ 102.4/508.0 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------- 184.3/508.0 kB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 286.7/508.0 kB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 358.4/508.0 kB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 471.0/508.0 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 508.0/508.0 kB 1.6 MB/s eta 0:00:00
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
import pandas as pd
pd.read_csv("Nifty50_Companieslist.csv")
# Out:
#                           Industry      Symbol Series     ISIN Code
# 0                  Metals & Mining    ADANIENT     EQ  INE423A01024
# 1                         Services  ADANIPORTS     EQ  INE742F01042
# 2                       Healthcare  APOLLOHOSP     EQ  INE437A01024
# 3                Consumer Durables  ASIANPAINT     EQ  INE021A01026
# 4               Financial Services    AXISBANK     EQ  INE238A01034
# 5   Automobile and Auto Components  BAJAJ-AUTO     EQ  INE917I01010
# 6               Financial Services  BAJFINANCE     EQ  INE296A01024
# 7               Financial Services  BAJAJFINSV     EQ  INE918I01026
# 8       Oil Gas & Consumable Fuels        BPCL     EQ  INE029A01011
# 9                Telecommunication  BHARTIARTL     EQ  INE397D01024
# 10      Fast Moving Consumer Goods   BRITANNIA     EQ  INE216A01030
# 11                      Healthcare       CIPLA     EQ  INE059A01026
# 12      Oil Gas & Consumable Fuels   COALINDIA     EQ  INE522F01014
# ...

# %%
# Example usage
import mv
stocks = ["TCS", "MSFT", "WIPRO"]
start_date = "2020-01-01"
end_date = "2023-02-01"
# api_key = "1F4922R2LOBSW9O1"

mvo = mv.MeanVarianceOptimization(stocks, start_date, end_date)
er = mvo.expected_returns()

print(er)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       4 end_date = "2023-02-01"
#       5 # api_key = "1F4922R2LOBSW9O1"
# ----> 7 mvo = mv.MeanVarianceOptimization(stocks, start_date, end_date)
#       8 er = mvo.expected_returns()
#      10 print(er)
#
# NameError: name 'mv' is not defined

# %%
from random import randrange 
heads = tails = 0
for i in range(100):
    if randrange(4)==randrange(4): heads = heads + 1
    else: tails = tails + 1
print(heads)
# Out:
# 29

# %%
import mv
if __name__ == "__main__":
    stocks = ["TCS", "LT", "SBIN"]
    start_date = "2020-01-01"
    end_date = "2023-02-01"
    
    # Assuming historical stock data is stored in the 'historical_data' folder
    mvo = mv.MeanVarianceOptimization(stocks, start_date, end_date, data_dir='historical_data')
    er = mvo.expected_returns()
    print(er)
# Out:
# Data for TCS not found in historical_data
# Data for LT not found in historical_data
# Data for SBIN not found in historical_data
# Series([], Name: mkt, dtype: float64)
# c:\Users\jrnat\qiskit1x\cwq\Lib\site-packages\numpy\lib\function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# c:\Users\jrnat\qiskit1x\cwq\Lib\site-packages\numpy\core\_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# c:\Users\jrnat\qiskit1x\cwq\Lib\site-packages\pandas\core\frame.py:11211: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# c:\Users\jrnat\qiskit1x\cwq\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Users\jrnat\qiskit1x\cwq\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ...
